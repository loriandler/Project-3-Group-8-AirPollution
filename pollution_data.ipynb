# %%
# Import dependencies
import pandas as pd

# Read CSV file for 2021
HAPS2021=pd.read_csv("daily_HAPS_2021_4states.csv")

HAPS2021
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0               6            1         7           43218    3  37.687526
# 1               6            1         7           43218    3  37.687526
# 2               6            1         7           43218    3  37.687526
# 3               6            1         7           43218    3  37.687526
# 4               6            1         7           43218    3  37.687526
# ...           ...          ...       ...             ...  ...        ...
# 18023          48          355        34           88128    5  27.811817
# 18024          48          355        34           88128    5  27.811817
# 18025          48          355        34           88128    5  27.811817
# 18026          48          355        34           88128    5  27.811817
# 18027          48          355        34           88128    5  27.811817
#
#         Longitude  Datum Parameter Name Sample Duration  ...  AQI Method Code  \
# ...

# %%
# Read CSV file for 2020
HAPS2020=pd.read_csv("daily_HAPS_2020_4states.csv")

HAPS2020
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0               6            1         7           43218    3  37.687526
# 1               6            1         7           43218    3  37.687526
# 2               6            1         7           43218    3  37.687526
# 3               6            1         7           43218    3  37.687526
# 4               6            1         7           43218    3  37.687526
# ...           ...          ...       ...             ...  ...        ...
# 18081          48          203         2           88128    5  32.669001
# 18082          48          203         2           88128    5  32.669001
# 18083          48          203         2           88128    5  32.669001
# 18084          48          203         2           88128    5  32.669001
# 18085          48          203         2           88128    5  32.669001
#
#         Longitude  Datum Parameter Name Sample Duration  ...  AQI Method Code  \
# ...

# %%
# Join the datasets into one data frame
combined_2020_2021_df=pd.concat([HAPS2020, HAPS2021])
print(combined_2020_2021_df)
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0               6            1         7           43218    3  37.687526
# 1               6            1         7           43218    3  37.687526
# 2               6            1         7           43218    3  37.687526
# 3               6            1         7           43218    3  37.687526
# 4               6            1         7           43218    3  37.687526
# ...           ...          ...       ...             ...  ...        ...
# 18023          48          355        34           88128    5  27.811817
# 18024          48          355        34           88128    5  27.811817
# 18025          48          355        34           88128    5  27.811817
# 18026          48          355        34           88128    5  27.811817
# 18027          48          355        34           88128    5  27.811817
#
#         Longitude  Datum Parameter Name Sample Duration  ...  AQI Method Code  \
# ...

# %%
# Filter out by the Parameters: Benzene, Formaldehyde, 1,3 Butadiene and Lead PM2.5 LC
parameter_df=combined_2020_2021_df[(combined_2020_2021_df["Parameter Name"]=="Benzene") | (combined_2020_2021_df["Parameter Name"]=="Formaldehyde") | (combined_2020_2021_df["Parameter Name"]=="1,3-Butadiene") | (combined_2020_2021_df["Parameter Name"]=="Lead PM2.5 LC")]
parameter_df["Parameter Name"].unique()
# Out:
# array(['1,3-Butadiene', 'Benzene', 'Formaldehyde', 'Lead PM2.5 LC'],
#       dtype=object)

# %%
parameter_df
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0               6            1         7           43218    3  37.687526
# 1               6            1         7           43218    3  37.687526
# 2               6            1         7           43218    3  37.687526
# 3               6            1         7           43218    3  37.687526
# 4               6            1         7           43218    3  37.687526
# ...           ...          ...       ...             ...  ...        ...
# 18023          48          355        34           88128    5  27.811817
# 18024          48          355        34           88128    5  27.811817
# 18025          48          355        34           88128    5  27.811817
# 18026          48          355        34           88128    5  27.811817
# 18027          48          355        34           88128    5  27.811817
#
#         Longitude  Datum Parameter Name Sample Duration  ...  AQI Method Code  \
# ...
