# %%
# Import dependencies
import pandas as pd

# %% [markdown]
# END_COLUMNS = [date, lat, long, parameter name, concentration metric, concentration value, state, county, city]
# POLLUTANTS = ['1,3-Butadiene', 'Benzene', 'Formaldehyde', 'Lead PM2.5 LC', 'O3'....]
# YEARS = [2020, 2021]
# STATES = ['California', 'Minnesota', 'New York', 'Texas']

# %% [markdown]
# 1) read HAP_2020, HAP_2021, O3_2020, O3_2021...
#
# df = pd.read_csv("https://aqs.epa.gov/aqsweb/airdata/daily_44201_2022.zip", compression="zip")

# %%
# data information, define constants and functions

columns_2022 = ['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
       'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
       'Pollutant Standard', 'Date Local', 'Units of Measure', 'Event Type',
       'Observation Count', 'Observation Percent', 'Arithmetic Mean',
       '1st Max Value', '1st Max Hour', 'AQI', 'Method Code', 'Method Name',
       'Local Site Name', 'Address', 'State Name', 'County Name', 'City Name',
       'CBSA Name', 'Date of Last Change']

DROP_COLUMNS = ['State Code', 'County Code', 'Site Num', 'Datum', 'Sample Duration',
       'Pollutant Standard',  'Event Type','Observation Count', 'Observation Percent', 
        '1st Max Hour', 'Method Code', 'Method Name','Local Site Name', 'Address', 
       'CBSA Name', 'Date of Last Change']

# see https://aqs.epa.gov/aqsweb/airdata/FileFormats.html#_daily_summary_files
KEPT_COLUMNS = ['Parameter Code', 'POC','Latitude', 'Longitude','Parameter Name',
                'Date Local', 'Units of Measure', 'Arithmetic Mean','1st Max Value',
                'AQI','State Name', 'County Name', 'City Name']

STATES_4 = ['California', 'Minnesota', 'New York', 'Texas']

POLLUTANTS = ['Benzene', 'Formaldehyde', '1,3-Butadiene', 'Lead PM2.5 LC', 'Ozone', 'SO2', 'CO', 'NO2' ]

# %%
merge_df = pd.DataFrame()
for year in [2022, 2021, 2020]:
    for pollutant_code in [44201, 42401, 42101, 42602, "HAPS"]:
        url = f"https://aqs.epa.gov/aqsweb/airdata/daily_{pollutant_code}_{year}.zip"
        df = pd.read_csv(url, compression="zip")
        merge_df = pd.concat([merge_df, df], ignore_index=True)
        print(url, df.shape, merge_df.shape, list(df.columns) == list(columns_2022)) #, df.columns, sep="\n")
# Out:
# https://aqs.epa.gov/aqsweb/airdata/daily_44201_2022.zip (233601, 29) (233601, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_42401_2022.zip (178679, 29) (412280, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2022.zip (99645, 29) (511925, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_42602_2022.zip (92635, 29) (604560, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_HAPS_2022.zip (92579, 29) (697139, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_44201_2021.zip (390562, 29) (1087701, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_42401_2021.zip (303633, 29) (1391334, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2021.zip (173542, 29) (1564876, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_42602_2021.zip (158390, 29) (1723266, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_HAPS_2021.zip (319195, 29) (2042461, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_44201_2020.zip (391845, 29) (2434306, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_42401_2020.zip (323525, 29) (2757831, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_42101_2020.zip (180206, 29) (2938037, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_42602_2020.zip (158302, 29) (3096339, 29) True
# https://aqs.epa.gov/aqsweb/airdata/daily_HAPS_2020.zip (306277, 29) (3402616, 29) True

# %%
merge_df
# Out:
#          State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0                 1            3        10           44201    1  30.497478
# 1                 1            3        10           44201    1  30.497478
# 2                 1            3        10           44201    1  30.497478
# 3                 1            3        10           44201    1  30.497478
# 4                 1            3        10           44201    1  30.497478
# ...             ...          ...       ...             ...  ...        ...
# 3402611          80            2        14           88136    5  32.633671
# 3402612          80            2        14           88136    5  32.633671
# 3402613          80            2        14           88136    5  32.633671
# 3402614          80            2        14           88136    5  32.633671
# 3402615          80            2        14           88136    5  32.633671
#
#           Longitude  Datum   Parameter Name          Sample Duration  ...  \
# 0        -87.880258  NAD83            Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 1        -87.880258  NAD83            Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 2        -87.880258  NAD83            Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 3        -87.880258  NAD83            Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 4        -87.880258  NAD83            Ozone  8-HR RUN AVG BEGIN HOUR  ...
# ...             ...    ...              ...                      ...  ...
# 3402611 -115.504995  WGS84  Nickel PM2.5 LC                  24 HOUR  ...
# 3402612 -115.504995  WGS84  Nickel PM2.5 LC                  24 HOUR  ...
# 3402613 -115.504995  WGS84  Nickel PM2.5 LC                  24 HOUR  ...
# 3402614 -115.504995  WGS84  Nickel PM2.5 LC                  24 HOUR  ...
# 3402615 -115.504995  WGS84  Nickel PM2.5 LC                  24 HOUR  ...
#
#           AQI Method Code                                        Method Name  \
# 0        35.0         NaN                                                 -
# 1        50.0         NaN                                                 -
# 2        51.0         NaN                                                 -
# 3        40.0         NaN                                                 -
# 4        77.0         NaN                                                 -
# ...       ...         ...                                                ...
# 3402611   NaN       811.0  Met One SASS/SuperSASS Teflon - Energy Dispers...
# 3402612   NaN       811.0  Met One SASS/SuperSASS Teflon - Energy Dispers...
# 3402613   NaN       811.0  Met One SASS/SuperSASS Teflon - Energy Dispers...
# 3402614   NaN       811.0  Met One SASS/SuperSASS Teflon - Energy Dispers...
# 3402615   NaN       811.0  Met One SASS/SuperSASS Teflon - Energy Dispers...
#
#                                            Local Site Name  \
# 0                                        FAIRHOPE, Alabama
# 1                                        FAIRHOPE, Alabama
# 2                                        FAIRHOPE, Alabama
# 3                                        FAIRHOPE, Alabama
# 4                                        FAIRHOPE, Alabama
# ...                                                    ...
# 3402611  COBACH, CALLE GUADALAJARA JUST SOUTH OF AVENID...
# 3402612  COBACH, CALLE GUADALAJARA JUST SOUTH OF AVENID...
# 3402613  COBACH, CALLE GUADALAJARA JUST SOUTH OF AVENID...
# 3402614  COBACH, CALLE GUADALAJARA JUST SOUTH OF AVENID...
# 3402615  COBACH, CALLE GUADALAJARA JUST SOUTH OF AVENID...
#
#                                                    Address         State Name  \
# 0        FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...            Alabama
# 1        FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...            Alabama
# 2        FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...            Alabama
# 3        FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...            Alabama
# 4        FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...            Alabama
# ...                                                    ...                ...
# 3402611           COBACH, COLEGIO DE BACHILLERES, MEXICALI  Country Of Mexico
# 3402612           COBACH, COLEGIO DE BACHILLERES, MEXICALI  Country Of Mexico
# 3402613           COBACH, COLEGIO DE BACHILLERES, MEXICALI  Country Of Mexico
# 3402614           COBACH, COLEGIO DE BACHILLERES, MEXICALI  Country Of Mexico
# 3402615           COBACH, COLEGIO DE BACHILLERES, MEXICALI  Country Of Mexico
#
#                    County Name  City Name                  CBSA Name  \
# 0                      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 1                      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 2                      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 3                      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# 4                      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL
# ...                        ...        ...                        ...
# 3402611  BAJA CALIFORNIA NORTE   Mexicali                        NaN
# 3402612  BAJA CALIFORNIA NORTE   Mexicali                        NaN
# 3402613  BAJA CALIFORNIA NORTE   Mexicali                        NaN
# 3402614  BAJA CALIFORNIA NORTE   Mexicali                        NaN
# 3402615  BAJA CALIFORNIA NORTE   Mexicali                        NaN
#
#          Date of Last Change
# 0                 2022-09-08
# 1                 2022-09-08
# 2                 2022-09-08
# 3                 2022-09-08
# 4                 2022-09-08
# ...                      ...
# 3402611           2021-04-01
# 3402612           2021-04-01
# 3402613           2021-04-01
# 3402614           2021-04-01
# 3402615           2021-04-01
#
# [3402616 rows x 29 columns]

# %%
drop_col_df = merge_df.drop(DROP_COLUMNS, 1)
drop_col_df
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_20576\101284811.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   drop_col_df = merge_df.drop(DROP_COLUMNS, 1)
#          Parameter Code  POC   Latitude   Longitude   Parameter Name  \
# 0                 44201    1  30.497478  -87.880258            Ozone
# 1                 44201    1  30.497478  -87.880258            Ozone
# 2                 44201    1  30.497478  -87.880258            Ozone
# 3                 44201    1  30.497478  -87.880258            Ozone
# 4                 44201    1  30.497478  -87.880258            Ozone
# ...                 ...  ...        ...         ...              ...
# 3402611           88136    5  32.633671 -115.504995  Nickel PM2.5 LC
# 3402612           88136    5  32.633671 -115.504995  Nickel PM2.5 LC
# 3402613           88136    5  32.633671 -115.504995  Nickel PM2.5 LC
# 3402614           88136    5  32.633671 -115.504995  Nickel PM2.5 LC
# 3402615           88136    5  32.633671 -115.504995  Nickel PM2.5 LC
#
#          Date Local             Units of Measure  Arithmetic Mean  \
# 0        2022-02-28            Parts per million         0.038000
# 1        2022-03-01            Parts per million         0.037235
# 2        2022-03-02            Parts per million         0.038235
# 3        2022-03-03            Parts per million         0.024333
# 4        2022-03-04            Parts per million         0.049647
# ...             ...                          ...              ...
# 3402611  2020-12-05  Micrograms/cubic meter (LC)         0.000000
# 3402612  2020-12-11  Micrograms/cubic meter (LC)         0.001000
# 3402613  2020-12-17  Micrograms/cubic meter (LC)         0.000000
# 3402614  2020-12-23  Micrograms/cubic meter (LC)         0.000000
# 3402615  2020-12-29  Micrograms/cubic meter (LC)         0.000000
#
#          1st Max Value   AQI         State Name            County Name  \
# 0                0.038  35.0            Alabama                Baldwin
# 1                0.054  50.0            Alabama                Baldwin
# 2                0.055  51.0            Alabama                Baldwin
# 3                0.043  40.0            Alabama                Baldwin
# 4                0.063  77.0            Alabama                Baldwin
# ...                ...   ...                ...                    ...
# 3402611          0.000   NaN  Country Of Mexico  BAJA CALIFORNIA NORTE
# 3402612          0.001   NaN  Country Of Mexico  BAJA CALIFORNIA NORTE
# 3402613          0.000   NaN  Country Of Mexico  BAJA CALIFORNIA NORTE
# 3402614          0.000   NaN  Country Of Mexico  BAJA CALIFORNIA NORTE
# 3402615          0.000   NaN  Country Of Mexico  BAJA CALIFORNIA NORTE
#
#         City Name
# 0        Fairhope
# 1        Fairhope
# 2        Fairhope
# 3        Fairhope
# 4        Fairhope
# ...           ...
# 3402611  Mexicali
# 3402612  Mexicali
# 3402613  Mexicali
# 3402614  Mexicali
# 3402615  Mexicali
#
# [3402616 rows x 13 columns]

# %%
# guidance from https://stackoverflow.com/questions/12065885/filter-dataframe-rows-if-value-in-column-is-in-a-set-list-of-values 
drop_state_df = drop_col_df[drop_col_df['State Name'].isin(STATES_4)]
drop_state_df
# Out:
#          Parameter Code  POC   Latitude   Longitude Parameter Name  \
# 13728             44201    1  37.687526 -121.784217          Ozone
# 13729             44201    1  37.687526 -121.784217          Ozone
# 13730             44201    1  37.687526 -121.784217          Ozone
# 13731             44201    1  37.687526 -121.784217          Ozone
# 13732             44201    1  37.687526 -121.784217          Ozone
# ...                 ...  ...        ...         ...            ...
# 3369341           45201    1  27.501826  -99.502984        Benzene
# 3369342           45201    1  27.501826  -99.502984        Benzene
# 3369343           45201    1  27.501826  -99.502984        Benzene
# 3369344           45201    1  27.501826  -99.502984        Benzene
# 3369345           45201    1  27.501826  -99.502984        Benzene
#
#          Date Local          Units of Measure  Arithmetic Mean  1st Max Value  \
# 13728    2022-01-01         Parts per million         0.013588          0.032
# 13729    2022-01-02         Parts per million         0.008059          0.020
# 13730    2022-01-03         Parts per million         0.029765          0.033
# 13731    2022-01-04         Parts per million         0.025706          0.032
# 13732    2022-01-05         Parts per million         0.022941          0.029
# ...             ...                       ...              ...            ...
# 3369341  2020-12-05  Parts per billion Carbon         3.540000          3.540
# 3369342  2020-12-11  Parts per billion Carbon         4.140000          4.140
# 3369343  2020-12-17  Parts per billion Carbon         3.480000          3.480
# 3369344  2020-12-23  Parts per billion Carbon         3.780000          3.780
# 3369345  2020-12-29  Parts per billion Carbon         1.860000          1.860
#
#           AQI  State Name County Name  City Name
# 13728    30.0  California     Alameda  Livermore
# 13729    19.0  California     Alameda  Livermore
# 13730    31.0  California     Alameda  Livermore
# 13731    30.0  California     Alameda  Livermore
# 13732    27.0  California     Alameda  Livermore
# ...       ...         ...         ...        ...
# 3369341   NaN       Texas        Webb     Laredo
# 3369342   NaN       Texas        Webb     Laredo
# 3369343   NaN       Texas        Webb     Laredo
# 3369344   NaN       Texas        Webb     Laredo
# 3369345   NaN       Texas        Webb     Laredo
#
# [860077 rows x 13 columns]

# %%
drop_pollutants_df = drop_state_df[drop_state_df['Parameter Name'].isin(POLLUTANTS)]
drop_pollutants_df
# Out:
#          Parameter Code  POC   Latitude   Longitude Parameter Name  \
# 13728             44201    1  37.687526 -121.784217          Ozone
# 13729             44201    1  37.687526 -121.784217          Ozone
# 13730             44201    1  37.687526 -121.784217          Ozone
# 13731             44201    1  37.687526 -121.784217          Ozone
# 13732             44201    1  37.687526 -121.784217          Ozone
# ...                 ...  ...        ...         ...            ...
# 3369341           45201    1  27.501826  -99.502984        Benzene
# 3369342           45201    1  27.501826  -99.502984        Benzene
# 3369343           45201    1  27.501826  -99.502984        Benzene
# 3369344           45201    1  27.501826  -99.502984        Benzene
# 3369345           45201    1  27.501826  -99.502984        Benzene
#
#          Date Local          Units of Measure  Arithmetic Mean  1st Max Value  \
# 13728    2022-01-01         Parts per million         0.013588          0.032
# 13729    2022-01-02         Parts per million         0.008059          0.020
# 13730    2022-01-03         Parts per million         0.029765          0.033
# 13731    2022-01-04         Parts per million         0.025706          0.032
# 13732    2022-01-05         Parts per million         0.022941          0.029
# ...             ...                       ...              ...            ...
# 3369341  2020-12-05  Parts per billion Carbon         3.540000          3.540
# 3369342  2020-12-11  Parts per billion Carbon         4.140000          4.140
# 3369343  2020-12-17  Parts per billion Carbon         3.480000          3.480
# 3369344  2020-12-23  Parts per billion Carbon         3.780000          3.780
# 3369345  2020-12-29  Parts per billion Carbon         1.860000          1.860
#
#           AQI  State Name County Name  City Name
# 13728    30.0  California     Alameda  Livermore
# 13729    19.0  California     Alameda  Livermore
# 13730    31.0  California     Alameda  Livermore
# 13731    30.0  California     Alameda  Livermore
# 13732    27.0  California     Alameda  Livermore
# ...       ...         ...         ...        ...
# 3369341   NaN       Texas        Webb     Laredo
# 3369342   NaN       Texas        Webb     Laredo
# 3369343   NaN       Texas        Webb     Laredo
# 3369344   NaN       Texas        Webb     Laredo
# 3369345   NaN       Texas        Webb     Laredo
#
# [294297 rows x 13 columns]
