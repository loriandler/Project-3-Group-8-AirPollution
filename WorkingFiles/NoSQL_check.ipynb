# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# refer to NoSQL challenge for guidance on code

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'proj3', 'proj4', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['proj3']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['air_pollution']

# %%
# review a document in the establishments collection
print(db.air_pollution.find_one())
pprint(db.air_pollution.find_one())
# Out:
# {'_id': ObjectId('65357fc5fb0711ca88fb77d9'), '': 13728, 'parameter_code': 44201, 'POC': 1, 'lat': 37.687526, 'lon': -121.784217, 'parameter_name': 'Ozone', 'date_local': '2022-01-01', 'units_of_measure': 'Parts per million', 'arithmetic_mean': 0.013588, 'first_max_value': 0.032, 'AQI': 30.0, 'state_name': 'California', 'county_name': 'Alameda', 'city_name': 'Livermore'}
# {'': 13728,
#  'AQI': 30.0,
#  'POC': 1,
#  '_id': ObjectId('65357fc5fb0711ca88fb77d9'),
#  'arithmetic_mean': 0.013588,
#  'city_name': 'Livermore',
#  'county_name': 'Alameda',
#  'date_local': '2022-01-01',
#  'first_max_value': 0.032,
#  'lat': 37.687526,
#  'lon': -121.784217,
#  'parameter_code': 44201,
#  'parameter_name': 'Ozone',
#  'state_name': 'California',
#  'units_of_measure': 'Parts per million'}

# %%
for uniqueLat in db.air_pollution.find().distinct('lat'):
    print(uniqueLat)
# Out:
# 26.200335
# 26.22621
# 27.76534
# 27.804489
# 27.832413
# 28.836214
# 28.88044
# 29.043759
# 29.1307
# 29.254474
# 29.275381
# 29.30265
# 29.352911
# 29.385234
# 29.51509
# 29.520443
# 29.529432
# 29.583047
# 29.623889
# 29.625556
# 29.632058
# 29.670025
# 29.686389
# 29.695729
# 29.7216
# 29.723333
# 29.727931
# 29.733726
# 29.758889
# 29.767997
# 29.772915
# 29.802707
# 29.81453
# 29.823319
# 29.828086
# 29.834167
# 29.8442
# 29.863957
# 29.897516
# 29.901036
# 29.9425
# 29.979958
# 30.036422
# 30.039524
# 30.085263
# 30.153675
# 30.350302
# 30.35386
# 30.354944
# 30.483163
# 30.7017
# 31.088002
# 31.122419
# 31.168889
# 31.653086
# 31.6675
# 31.746775
# 31.765685
# 31.785769
# 31.797813
# 31.86247
# 31.893913
# 31.9041
# 32.031934
# 32.175417
# 32.277929
# 32.280422
# 32.344027
# 32.353595
# 32.378696
# 32.442304
# 32.470228
# 32.482083
# 32.564968
# 32.57816
# 32.631242
# 32.65637
# 32.664753
# 32.669001
# 32.67618
# 32.676451
# 32.710177
# 32.789565
# 32.79222
# 32.80581
# ...

# %%
for uniqueLon in db.air_pollution.find().distinct('lon'):
    print(uniqueLon)
# Out:
# -124.17949
# -122.818294
# -122.520004
# -122.399044
# -122.364852
# -122.356811
# -122.282347
# -122.263376
# -122.25556
# -122.237976
# -122.233229
# -122.20337
# -122.190834
# -122.169935
# -122.134467
# -122.092766
# -122.075624
# -122.031547
# -122.026154
# -121.99887
# -121.98822
# -121.979675
# -121.94986
# -121.934188
# -121.903019
# -121.894898
# -121.849783
# -121.84047
# -121.820362
# -121.784217
# -121.7734
# -121.73333
# -121.73269
# -121.641918
# -121.623271
# -121.618549
# -121.617309
# -121.600031
# -121.57646
# -121.574684
# -121.503795
# -121.49311
# -121.442495
# -121.420838
# -121.368014
# -121.3621
# -121.338353
# -121.281414
# -121.26498
# -121.211131
# -121.164457
# -121.15688
# -121.126371
# -121.09959
# -121.055608
# -121.003373
# -120.994212
# -120.953832
# -120.84271
# -120.836008
# -120.821916
# -120.764426
# -120.680277
# -120.66617
# -120.656912
# -120.56388
# -120.50103
# -120.4575
# -120.433671
# -120.428717
# -120.382331
# -120.378551
# -120.23135
# ...

# %%
# assign the collection to a variable
air_pollution = db['air_pollution']
